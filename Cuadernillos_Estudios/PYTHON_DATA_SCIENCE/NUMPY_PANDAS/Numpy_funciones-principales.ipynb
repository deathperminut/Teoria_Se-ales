# %%
import numpy as np

# %%
arr=np.random.randint(1,20,10)

arr

# %%
matriz=arr.reshape(2,5)
matriz

# %%
print(arr.max()) ## TOMA EL NUMERO MAS GRANDE DEL ARREGLO
print(matriz.max())

# %%
## AHORA YO PUEDO DEFINIR PARA CUAL FILA O COLUMNA VER EL MAXIMO
matriz.max(1) ## TOMANDO EL EJE1 ES DECIR FILAS

# %%
matriz.max(0) ## CERO ES PARA COLUMNAS

# %%
### ARGMAX, ME DEVUELVE ES EL INDICE DEL MAXIMO DE LA PRIMERA OCURRENCIA
arr.argmax()

# %%
matriz.argmax(0)

# %%
arr.min()
print(matriz.min(0))

# %%
arr

# %%
### ME ENTREGA LA DIFERENCIA DEL MAS ALTO AL MAS BAJO
arr.ptp() ## 19-2

# %%
matriz.ptp(1) ## POR FILAS

# %%
np.percentile(arr,50) ### VALOR QUE SE ENCUENTRA EN LA MITAD LA MEDIANA CUANDO HABLAMOS
### DEL PERCENTIL 50

# %%
### ORDENAR DE MENOR A MAYOR LOS NUMEROS DEL ARREGLO
np.sort(arr)

# %%
###MEDIANA
print(np.median(arr))
print(np.percentile(arr,50))

### MEDIAN(ARREGLO,EJE)
## 0 COLUMNAS
## 1 FILAS

# %%
np.std(arr) ### DESVIACIÓN ESTANDAR

# %%
np.var(arr) ### VARIANZA

# %%
np.mean(arr)

# %% [markdown]
# ### CONCATENAR

# %%
### CONCATENAR 
a=np.array([[1,2],[3,4]]) ## CREAMOS UNA MATRIZ
a

# %%
b=np.array([5,6])
b

# %%
print(a.ndim)
print(b.ndim)

# %%
##PARA CONCATENAR DEBEN TENER LA MISMA DIMENSION
b=np.expand_dims(b,axis=0)
print(b.ndim)

# %%
## AHORA SI CONCATENAMOS
np.concatenate((a,b),axis=0)

# %%
#TRANSPUESTA
b.T
## SI QUIERO AGREGARLA A MANERA DE COLUMNA
np.concatenate((a,b.T),axis=1)

# %%
##### MAS FUNCIONES 
## https://numpy.org/doc/stable/reference/routines.math.html
## https://numpy.org/doc/stable/reference/routines.statistics.html

# %% [markdown]
# ## COPY

# %%
ARREGLO2=arr.copy()
ARREGLO2

# %% [markdown]
# CAMBIAR VARIOS VALORES A CIERTOS NUMEROS

# %%
ARREGLO2[:]=100 ## TODOS LOS VALORES LOS PONGO EN 100
ARREGLO2
