# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../input/datos-excel/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv")
df.head(2)

# %%
df.info() ## SIRVE PARA DESCRIBIR EL DATAFRAME

# %%
df.describe() ## ME DA CIERTOS DATOS DE LAS COLUMNAS NUMERICAS OJOOOOO

# %%
## PARECIDO AL HEAD SOLO QUE ME ENSEÑA SON LOS ULTIMOS
df.tail(2)

# %%
### ME INDICA CUANTA MEMORIA ESTOY USANDO EN MI DATAFRAME

df.memory_usage(deep=True)
"""
AL NIVEL DEL DATASETS Y AL NIVEL DE CADA COLUMNA

- LOS STRING GENERALMENTE OCUPAN MAS MEMORIA 

"""

# %% [markdown]
# CONTABILIZAR DATOS

# %%
df["Author"].value_counts() ### CUENTA CUANTOS VALORES TENGO POR CADA UNO DE LOS AUTORES

# %%
df=df.append(df.iloc[0]) ## AGREGO UN VALOR DUPLICADO
df

# %% [markdown]
# ELIMINAR VALORES DUPLICADOS

# %%
df.drop_duplicates() ## ME ELIMINA LOS DUPLICADOS QUE TENGO EN LOS DATOS

####df.drop_duplicates(keep="last") DEJA EL ULTIMO Y ELIMINA LOS PRIMEROS

# %% [markdown]
# ORGANIZAR VALORES

# %%
df.sort_values("Year") ## ORDENAR POR CIERTA CONDICIÓN
### HACERLO DE MANERA DESCENTENDE df.sort_values("Year",ascending=False)

# %% [markdown]
# ### GROUPBY

# %%
### FUNCIONES DE AGREGACIÓN
### AGRUPA INFORMACIÓN DE CIERTAS SECCIONES 
df.groupby("Author").count() ### NECESITO UNA COLUMNA POR LA CUAL VAMOS A AGRUPAR

# %%
### MUCHAS DE LAS FUNCIONES DE NUMPY SIRVEN PARA LOS DATAFRAMES 
### YA QUE PARTEN DE LAS ESTRUCTURAS DE NUMPÝ
